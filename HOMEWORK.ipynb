# %% [markdown]
# # 1 . you have to write a fun which will take string and return a len of it without using a inbuilt fun len.

# %%
import ipdb
def takeStr(a):
    count=0
    for i in a:
        for j in i:
            count =count+1
        
    
    
    
    
    return count

# %%
takeStr("Welcome to Data Science world")
# Out:
# 29

# %%
takeStr("hi")
# Out:
# 2

# %% [markdown]
# # 2>4 . write a fun which will take another function as an input and return me an output

# %%
def test1(fun1):
    def now():
        print("now")
        fun1()
        print("exe")
    return now
def hello():
    print("Rajneesh")
hello= test1(hello)
hello()
# Out:
# now
# Rajneesh
# exe

# %% [markdown]
# # 3> 5. write a function whihc will take multiple list as a input and give me concatnation of all the element as and output

# %%
def testing(a,b,c):
    result1=a+b
    result2=a+c
    return (result1,result2)

a=[1,2,3,4]
b=[1,1,1,1]
c=[2,2,2,2]

result1,result2=testing(a,b,c)

# %% [markdown]
# # 4> 8  . write a function which will be able to show your system configuration .

# %%
import platform as pt

sys_config =pt.uname()
print(f"system: {sys_config.system}")
print(f"node: {sys_config.node}")
print(f"release: {sys_config.release}")
print(f"version: {sys_config.version}")
print(f"machine: {sys_config.machine}")
print(f"processor: {sys_config.processor}")
# Out:
# system: Windows
# node: LAPTOP-JRRVQ7RJ
# release: 10
# version: 10.0.19041
# machine: AMD64
# processor: Intel64 Family 6 Model 140 Stepping 1, GenuineIntel

# %% [markdown]
# # 5> 9 . write a function which will be able to show date and time

# %%
import datetime

current_dt= datetime.datetime.now()
print(current_dt)
# Out:
# 2021-12-26 22:05:10.192987

# %% [markdown]
# # 6> 13. write a function which will be able to shutdonw your system

# %%
import os

shut = input("Do you want to close your system? (Yes/No)")

# %% [markdown]
# # 7> 17. write a function to read a word file

# %%
pip install docx2txt
# Out:
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3966 sha256=05be0e1f320418e3759182e42af79cf9e7b7a6a7d5a127f1fed599763255255f
#   Stored in directory: c:\users\rajneesh bharti\appdata\local\pip\cache\wheels\55\f0\2c\81637d42670985178b77df6d41b9b6c6dc18c94818447414b9
# Successfully built docx2txt
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx2txt

# %%
wordfile_read=docx2txt.process("Rajneesh -Application Developer__Available...docx")

# %%
wordfile_read
# Out:
# "Rajneesh Bharti\n\nApplication Developer\n\n\uf3cd: +91 7000650240\n\n\uf0e0: rajneeshbharti043@gmail.com\n\n\uf08c:www.linkedin.com/in/rajneesh-18\n\n\uf015: BTM, Bangalore, Karnataka 560068\n\n\n\nOBJECTIVE\n\n\n\nA challenging career in the field of IT-Software especially Python Programmer where my Strong knowledge and experience in Programming Concepts and Methodologies can be utilized for the growth of Organization.\n\n\n\nPROFESSIONAL SUMMARY\n\n\t\t2.8 Years of experience in Web-Applications design, development, implementation, and testing using Python and Django Technologies.\n\n\t\tGood working experience with Core Python, Django, Web Services (Django rest framework), MVT, ORM, HTML, CSS & JavaScript,logging,debugging,pandas,numpy.\n\n\t\tExpertise in OOP's Object-Oriented Programming like Python.\n\n\t\tGood experience in open-source frameworks like Django.\n\n\t\tUsed GIT for version management of programs.\n\n\t\tGood working experience in application development using I
# ...

# %% [markdown]
# # 8.> write a func to read a complete PDf file

# %%
import PyPDF2

# %%
def pdfreader():
    # create a pdf file object
    pdfFileObj = open('cv.pdf', 'rb')

    # create a pdf reader object
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

    for i in range(pdfReader.numPages):
        pageObj = pdfReader.getPage(i)
        print(pageObj.extractText())

    # closing the pdf file object
    pdfFileObj.close()

# %%
pdfreader()
# Out:
# Rajneesh Bhart
# i
#
# Application
#
# Developer
#
# :
#
# +91
#
# 7000650240
#
# :
#
# rajneeshbharti043@gmail.com
#
# :
# www.linkedin.com/in/rajneesh
# -
# 18
#
# :
#
# BTM,
#
# Bangalore,
# Karnataka
# 560068
#
#
# OBJECTIVE
#
#
# A
#
# challenging
#
# career
#
# in
#
# the
#
# field
#
# of
#
# IT
# -
# Software
#
# especially
#
# Python
#
# Programmer
#
# where
#
# my
#
# Strong
#
# knowledge
#
# and
#
# experience in
#
# Programming
#
# Concepts and
#
# Methodologies
#
# can
#
# be
#
# utilized for
#
# the
#
# growth
#
# of
#
# Organization.
#
#
# PROFESSIONAL
#
# SUMMARY
#
#
#
# 2.
# 8
#
# Years of experience in Web
# -
# Applications design, development, implementation, and
#
# testing
#
# using
#
# Python
#
# and
#
# Django
#
# Technologies.
#
#
#
# Good working experience with Core
# Python
# ,
# Django
# , Web Services (Django rest
#
# framework),
#
# MVT
# ,
#
# ORM
# ,
# HTML, CSS
#
# &
# JavaScript
# .
#
#
#
# Expertise
#
# in
#
# OOP's
#
# Object
# -
# Oriented
#
# ...

# %% [markdown]
# # 9.>6 . write a function which will be able to take a list as an input return an index of each element

# %%
def lstindex(a):
    for i in range(len(a)):
        print(i,a[i])

# %%
lstindex([1,2,3,2,3,5])
# Out:
# 0 1
# 1 2
# 2 3
# 3 2
# 4 3
# 5 5

# %% [markdown]
# # 10.>19 . write a function by which you can print an ip address of your system .

# %%
import socket

# %%
def ipad():
    hostname = socket.gethostname()
    IP_add = socket.gethostbyname(hostname)
    print("IP Address is:" + IP_add)

# %%
ipad()
# Out:
# IP Address is:192.168.101.9
